# %%
import pandas as pd

# %%
data = pd.read_csv('aadhar_enrolment_final.csv')

# %%
data.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'age_0_5', 'age_5_17',
#        'age_18_greater'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006029 entries, 0 to 1006028
# Data columns (total 7 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   date            1006029 non-null  object
#  1   state           1006029 non-null  object
#  2   district        1006029 non-null  object
#  3   pincode         1006029 non-null  int64
#  4   age_0_5         1006029 non-null  int64
#  5   age_5_17        1006029 non-null  int64
#  6   age_18_greater  1006029 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 53.7+ MB

# %%
data.shape
# Out:
# (1006029, 7)

# %%
data.duplicated().value_counts()
# Out:
# False    983072
# True      22957
# Name: count, dtype: int64

# %%
data.duplicated(
    subset=[
        'date','state','district','pincode',
        'age_0_5','age_5_17','age_18_greater'
    ]
).value_counts()
# Out:
# False    983072
# True      22957
# Name: count, dtype: int64

# %%
(data['state']=="100000").sum()
# Out:
# np.int64(22)

# %% [markdown]
# # District Report

# %%
import re

district_view = (
    data[['state', 'district']]
    .dropna()
    .assign(
        district_norm=lambda df:
            df['district']
            .str.lower()
            .str.strip()
            .str.replace(r'[()\-\s]+', ' ', regex=True)
    .str.replace(r'[^a-z0-9 ]', '', regex=True)
    )
)

# %%
variation_summary = (
    district_view
    .groupby(['state', 'district_norm'])['district']
    .nunique()
    .reset_index(name='no_of_variations')
    .query('no_of_variations > 1')
)

# %%
district_variations = (
    district_view
    .merge(
        variation_summary[['state', 'district_norm']],
        on=['state', 'district_norm']
    )
    .groupby(['state', 'district_norm'])['district']
    .unique()
    .reset_index(name='district_spellings')
)

# %%
district_variations
# Out:
#                 state        district_norm  \
# 0               Bihar       aurangabad bh
# 1        Chhattisgarh       janjgir champa
# 2   Jammu and Kashmir                punch
# 3           Jharkhand  seraikela kharsawan
# 4           Karnataka               yadgir
# 5              Odisha                angul
# 6              Odisha               anugul
# 7              Odisha               jajpur
# 8              Odisha              nuapada
# 9              Punjab    sas nagar mohali
# 10          Rajasthan                 deeg
# 11          Telangana   medchal malkajgiri
# 12          Telangana    medchalmalkajgiri
# 13        West Bengal              hooghly
# 14        West Bengal               howrah
# 15        West Bengal              kolkata
# 16        West Bengal                malda
# 17        West Bengal                nadia
# 18        West Bengal    south 24 parganas
#
#                                    district_spellings
# 0                    [Aurangabad(bh), Aurangabad(BH)]
# 1   [Janjgir-champa, Janjgir - Champa, Janjgir Cha...
# 2                                      [Punch, punch]
# 3          [Seraikela-Kharsawan, Seraikela-kharsawan]
# 4                                    [Yadgir, yadgir]
# 5                                      [Angul, ANGUL]
# 6                                    [Anugul, ANUGUL]
# 7                            [JAJPUR, jajpur, Jajpur]
# 8                                  [Nuapada, NUAPADA]
# 9           [SAS Nagar (Mohali), S.A.S Nagar(Mohali)]
# 10                                      [Deeg , Deeg]
# 11           [Medchal-malkajgiri, Medchal Malkajgiri]
# 12           [Medchal−malkajgiri, Medchal?malkajgiri]
# 13                        [Hooghly, hooghly, HOOGHLY]
# 14                                   [Howrah, HOWRAH]
# 15                                 [Kolkata, KOLKATA]
# 16                                     [Malda, MALDA]
# 17                              [Nadia, NADIA, nadia]
# 18             [South 24 Parganas, South 24 parganas]

# %%
district_view = (
    data[['state','district']]
    .drop_duplicates()
    .assign(
        norm_space=lambda df:
            df['district']
            .str.lower()
            .str.replace(r'[()\-\s]+', '', regex=True)
            .str.replace(r'[^a-z0-9]', '', regex=True)
    )
)

# %%
(
    district_view
    .groupby(['state','norm_space'])['district']
    .unique()
    .reset_index(name='district_spellings')
    .query('district_spellings.str.len() > 1')
)
# Out:
#                   state          norm_space  \
# 23       Andhra Pradesh          karimnagar
# 27       Andhra Pradesh        kvrangareddy
# 28       Andhra Pradesh        mahabubnagar
# 117               Bihar        aurangabadbh
# 177        Chhattisgarh       janjgirchampa
# 215               Delhi           northeast
# 231             Gujarat         banaskantha
# 251             Gujarat         panchmahals
# 255             Gujarat         sabarkantha
# 257             Gujarat       surendranagar
# 270             Haryana             jhajjar
# 285             Haryana         yamunanagar
# 332   Jammu and Kashmir               punch
# 340           Jharkhand              bokaro
# 347           Jharkhand              garhwa
# 369           Jharkhand  seraikelakharsawan
# 372           Karnataka            bagalkot
# 386           Karnataka      chamarajanagar
# 398           Karnataka               gadag
# 402           Karnataka              haveri
# 417           Karnataka               udupi
# 421           Karnataka              yadgir
# 443      Madhya Pradesh          ashoknagar
# 460      Madhya Pradesh               harda
# 501         Maharashtra          ahmednagar
# 517         Maharashtra             gondiya
# 518         Maharashtra             hingoli
# 525         Maharashtra      mumbaisuburban
# 528         Maharashtra           nandurbar
# 544         Maharashtra              washim
# 602              Odisha               angul
# 604              Odisha              anugul
# 620              Odisha              jajpur
# 634              Odisha             nuapada
# 659              Orissa          kendrapara
# 706              Punjab      sasnagarmohali
# 725           Rajasthan                deeg
# 780          Tamil Nadu            namakkal
# 825           Telangana   medchalmalkajgiri
# 834           Telangana          rangareddy
# 842           Telangana       warangalurban
# 845             Tripura              dhalai
# 868       Uttar Pradesh           barabanki
# 904       Uttar Pradesh          kushinagar
# 920       Uttar Pradesh           raebareli
# 931       Uttar Pradesh      siddharthnagar
# 965         West Bengal          coochbehar
# 976         West Bengal             hooghly
# 977         West Bengal              howrah
# 983         West Bengal             kolkata
# 984         West Bengal               malda
# 989         West Bengal               nadia
# 1000        West Bengal     south24parganas
#
#                                      district_spellings
# 23                            [Karimnagar, Karim Nagar]
# 27                    [K.V.Rangareddy, K.v. Rangareddy]
# 28                        [Mahabub Nagar, Mahabubnagar]
# 117                    [Aurangabad(bh), Aurangabad(BH)]
# 177   [Janjgir-champa, Janjgir - Champa, Janjgir Cha...
# 215                        [North East, North East   *]
# 231                         [Banas Kantha, Banaskantha]
# 251                         [Panchmahals, Panch Mahals]
# 255                         [Sabarkantha, Sabar Kantha]
# 257                     [Surendra Nagar, Surendranagar]
# 270                                [Jhajjar, Jhajjar *]
# 285                         [Yamuna Nagar, Yamunanagar]
# 332                                      [Punch, punch]
# 340                                  [Bokaro, Bokaro *]
# 347                                  [Garhwa, Garhwa *]
# 369          [Seraikela-Kharsawan, Seraikela-kharsawan]
# 372                              [Bagalkot, Bagalkot *]
# 386                  [Chamarajanagar, Chamarajanagar *]
# 398                                    [Gadag, Gadag *]
# 402                                  [Haveri, Haveri *]
# 417                                    [Udupi, Udupi *]
# 421                                    [Yadgir, yadgir]
# 443                           [Ashok Nagar, Ashoknagar]
# 460                                    [Harda, Harda *]
# 501                           [Ahmednagar, Ahmed Nagar]
# 517                                [Gondiya, Gondiya *]
# 518                                [Hingoli, Hingoli *]
# 525              [Mumbai Suburban, Mumbai( Sub Urban )]
# 528                            [Nandurbar, Nandurbar *]
# 544                                  [Washim, Washim *]
# 602                                      [Angul, ANGUL]
# 604                                    [Anugul, ANUGUL]
# 620                            [JAJPUR, jajpur, Jajpur]
# 634                                  [Nuapada, NUAPADA]
# 659                          [Kendrapara, Kendrapara *]
# 706           [SAS Nagar (Mohali), S.A.S Nagar(Mohali)]
# 725                                       [Deeg , Deeg]
# 780                            [Namakkal, Namakkal   *]
# 825   [Medchal-malkajgiri, Medchal Malkajgiri, Medch...
# 834                           [Ranga Reddy, Rangareddy]
# 842                  [Warangal Urban, Warangal (urban)]
# 845                                 [Dhalai, Dhalai  *]
# 868                             [Bara Banki, Barabanki]
# 904             [Kushinagar, Kushi Nagar, Kushinagar *]
# 920                             [Rae Bareli, Raebareli]
# 931                   [Siddharthnagar, Siddharth Nagar]
# 965                           [Coochbehar, Cooch Behar]
# 976                         [Hooghly, hooghly, HOOGHLY]
# 977                                    [Howrah, HOWRAH]
# 983                                  [Kolkata, KOLKATA]
# 984                                      [Malda, MALDA]
# 989                               [Nadia, NADIA, nadia]
# 1000             [South 24 Parganas, South 24 parganas]

# %% [markdown]
# # Pincode

# %%
data['pincode_str'] = data['pincode'].astype(str)

pincode_format_issues = data[
    (~data['pincode_str'].str.match(r'^\d{6}$')) |
    (data['pincode'].isna())
]

pincode_format_issues[['state', 'district', 'pincode']]
# Out:
# Empty DataFrame
# Columns: [state, district, pincode]
# Index: []

# %%
pincode_district_conflict = (
    data.groupby('pincode')['district']
        .nunique()
        .reset_index(name='district_count')
)

problem_pincodes = pincode_district_conflict[
    pincode_district_conflict['district_count'] > 1
]

problem_pincodes
# Out:
#        pincode  district_count
# 1       110001               2
# 3       110003               3
# 7       110007               2
# 11      110011               2
# 16      110016               2
# ...        ...             ...
# 19451   855101               3
# 19453   855105               2
# 19455   855107               3
# 19459   855115               2
# 19462   855456               2
#
# [6576 rows x 2 columns]
